# %% [markdown]
# # Non-RAG GPT-5.6 Luna prompt comparison
#
# Run the same cancer-myth classification experiment without retrieved NCI PDQ evidence. The notebook evaluates the `basic`, `oncology_expert`, and `patient_education` prompts with the same model and strict Boolean JSON schema used by the RAG experiment.
#
# Set `OPENAI_API_KEY` before running. Each prompt writes a separate CSV, checkpoints every completed answer, and skips question IDs already present when resumed.

# %%
from __future__ import annotations

from concurrent.futures import as_completed, ThreadPoolExecutor
import csv
import json
import os
from pathlib import Path
import sys
import time


def find_project_root(start: Path) -> Path:
    for candidate in (start.resolve(), *start.resolve().parents):
        if (candidate / "pyproject.toml").is_file() and (candidate / "data").is_dir():
            return candidate
    raise FileNotFoundError("Could not find the project root.")


PROJECT_ROOT = find_project_root(Path.cwd())
DATASET_PATH = PROJECT_ROOT / "data" / "cancermyth_screening_dataset.json"
OUTPUT_DIR = PROJECT_ROOT / "non_rag" / "gpt-5.6-luna"

with DATASET_PATH.open(encoding="utf-8") as dataset_file:
    questions = json.load(dataset_file)

if not isinstance(questions, list) or not questions:
    raise ValueError("The dataset must be a non-empty JSON array.")
if any(not isinstance(row, dict) or "id" not in row or "question" not in row for row in questions):
    raise ValueError("Every dataset row must contain 'id' and 'question'.")
question_ids = [str(row["id"]) for row in questions]
if len(question_ids) != len(set(question_ids)):
    raise ValueError("Question IDs must be unique.")

PROMPT_KEYS = ("basic", "oncology_expert", "patient_education")
N_QUESTIONS = len(questions)  # Change to an integer to run only the first N questions.
N_WORKERS = max(1, os.cpu_count() or 4)
MAX_ATTEMPTS = 3

if isinstance(N_QUESTIONS, bool) or not isinstance(N_QUESTIONS, int):
    raise TypeError("N_QUESTIONS must be an integer.")
if not 1 <= N_QUESTIONS <= len(questions):
    raise ValueError(f"N_QUESTIONS must be between 1 and {len(questions)}.")
selected_questions = questions[:N_QUESTIONS]

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f"Selected questions: {len(selected_questions)} / {len(questions)}")
print(f"Available concurrent workers: {N_WORKERS}")
print(f"Output directory: {OUTPUT_DIR}")
# Out:
# Selected questions: 735 / 735
# Available concurrent workers: 16
# Output directory: D:\Personal Project\RAG In Cancer Myth\rag-cancer-myth\non_rag\gpt-5.6-luna

# %%
from rag.rag_model.config import LLMSettings
from rag.rag_model.llm import OpenAICompatibleBooleanClient
from rag.rag_model.prompts import render_prompt

settings = LLMSettings.from_environment()
settings.validate()
if settings.model != "gpt-5.6-luna":
    raise ValueError(f"This experiment requires gpt-5.6-luna; configured model is {settings.model!r}.")
if settings.base_url.rstrip("/") == "https://api.openai.com/v1" and not settings.api_key:
    raise RuntimeError("Set OPENAI_API_KEY before running the batch.")

client = OpenAICompatibleBooleanClient(settings)
print(f"Model: {settings.model}")
# Out:
# Model: gpt-5.6-luna

# %%
CSV_COLUMNS = ["question_id", "answer"]
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)


def load_completed_ids(output_path: Path) -> set[str]:
    completed: set[str] = set()
    if not output_path.exists() or output_path.stat().st_size == 0:
        return completed
    with output_path.open(newline="", encoding="utf-8") as existing_file:
        reader = csv.DictReader(existing_file)
        if reader.fieldnames != CSV_COLUMNS:
            raise ValueError(f"{output_path.name} must have columns {CSV_COLUMNS}.")
        for row in reader:
            question_id = row["question_id"].strip()
            if question_id in completed:
                raise ValueError(f"Duplicate question_id in {output_path.name}: {question_id}")
            if row["answer"] not in {"true", "false"}:
                raise ValueError(f"Invalid answer for question_id={question_id} in {output_path.name}.")
            completed.add(question_id)
    return completed


def classify_with_retry(prompt_key: str, question: str, question_id: object) -> str:
    prompt = render_prompt(prompt_key, question)
    for attempt in range(1, MAX_ATTEMPTS + 1):
        try:
            value = client.classify(prompt)  # No retrieved evidence: this is the non-RAG baseline.
            return "true" if value else "false"
        except Exception:
            if attempt == MAX_ATTEMPTS:
                raise
            delay_seconds = 2 ** (attempt - 1)
            print(f"[{prompt_key}] question_id={question_id} failed; retrying in {delay_seconds}s.")
            time.sleep(delay_seconds)
    raise AssertionError("Unreachable")


def run_prompt(prompt_key: str) -> Path:
    output_path = OUTPUT_DIR / f"answers_{prompt_key}.csv"
    completed_ids = load_completed_ids(output_path)
    pending = [row for row in selected_questions if str(row["id"]) not in completed_ids]
    completed_selected = len(selected_questions) - len(pending)
    worker_count = min(N_WORKERS, max(1, len(pending)))
    print(f"\n[{prompt_key}] selected={len(selected_questions)}, completed={completed_selected}, pending={len(pending)}, workers={worker_count}")

    write_header = not output_path.exists() or output_path.stat().st_size == 0
    with output_path.open("a", newline="", encoding="utf-8") as results_file:
        writer = csv.DictWriter(results_file, fieldnames=CSV_COLUMNS)
        if write_header:
            writer.writeheader()
            results_file.flush()
            os.fsync(results_file.fileno())

        with ThreadPoolExecutor(max_workers=worker_count) as executor:
            future_to_record = {
                executor.submit(
                    classify_with_retry,
                    prompt_key,
                    str(record["question"]),
                    record["id"],
                ): record
                for record in pending
            }
            for finished, future in enumerate(as_completed(future_to_record), start=1):
                record = future_to_record[future]
                writer.writerow({"question_id": record["id"], "answer": future.result()})
                results_file.flush()
                os.fsync(results_file.fileno())
                if finished == 1 or finished % 10 == 0 or finished == len(pending):
                    print(f"[{prompt_key}] saved {finished}/{len(pending)} pending answers.")

    print(f"[{prompt_key}] complete: {output_path}")
    return output_path


output_paths = [run_prompt(prompt_key) for prompt_key in PROMPT_KEYS]
# Out:
# [basic] selected=735, completed=0, pending=735, workers=16
# [basic] saved 1/735 pending answers.
# [basic] saved 10/735 pending answers.
# [basic] saved 20/735 pending answers.
# [basic] saved 30/735 pending answers.
# [basic] saved 40/735 pending answers.
# [basic] saved 50/735 pending answers.
# [basic] saved 60/735 pending answers.
# [basic] saved 70/735 pending answers.
# [basic] saved 80/735 pending answers.
# [basic] saved 90/735 pending answers.
# [basic] saved 100/735 pending answers.
# [basic] saved 110/735 pending answers.
# [basic] saved 120/735 pending answers.
# [basic] saved 130/735 pending answers.
# [basic] saved 140/735 pending answers.
# [basic] saved 150/735 pending answers.
# [basic] saved 160/735 pending answers.
# [basic] saved 170/735 pending answers.
# [basic] saved 180/735 pending answers.
# [basic] saved 190/735 pending answers.
# [basic] saved 200/735 pending answers.
# [basic] saved 210/735 pending answers.
# [basic] saved 220/735 pending answers.
# [basic] saved 230/735 pending answers.
# [basic] saved 240/735 pending answers.
# [basic] saved 250/735 pending answers.
# [basic] saved 260/735 pending answers.
# [basic] saved 270/735 pending answers.
# [basic] saved 280/735 pending answers.
# [basic] saved 290/735 pending answers.
# [basic] saved 300/735 pending answers.
# [basic] saved 310/735 pending answers.
# [basic] saved 320/735 pending answers.
# [basic] saved 330/735 pending answers.
# [basic] saved 340/735 pending answers.
# [basic] saved 350/735 pending answers.
# [basic] saved 360/735 pending answers.
# [basic] saved 370/735 pending answers.
# [basic] saved 380/735 pending answers.
# [basic] saved 390/735 pending answers.
# [basic] saved 400/735 pending answers.
# [basic] saved 410/735 pending answers.
# [basic] saved 420/735 pending answers.
# [basic] saved 430/735 pending answers.
# [basic] saved 440/735 pending answers.
# [basic] saved 450/735 pending answers.
# [basic] saved 460/735 pending answers.
# [basic] saved 470/735 pending answers.
# [basic] saved 480/735 pending answers.
# [basic] saved 490/735 pending answers.
# [basic] saved 500/735 pending answers.
# [basic] saved 510/735 pending answers.
# [basic] saved 520/735 pending answers.
# [basic] saved 530/735 pending answers.
# [basic] saved 540/735 pending answers.
# [basic] saved 550/735 pending answers.
# [basic] saved 560/735 pending answers.
# [basic] saved 570/735 pending answers.
# [basic] saved 580/735 pending answers.
# [basic] saved 590/735 pending answers.
# [basic] saved 600/735 pending answers.
# [basic] saved 610/735 pending answers.
# [basic] saved 620/735 pending answers.
# [basic] saved 630/735 pending answers.
# [basic] saved 640/735 pending answers.
# [basic] saved 650/735 pending answers.
# [basic] saved 660/735 pending answers.
# [basic] saved 670/735 pending answers.
# [basic] saved 680/735 pending answers.
# [basic] saved 690/735 pending answers.
# [basic] saved 700/735 pending answers.
# [basic] saved 710/735 pending answers.
# [basic] saved 720/735 pending answers.
# [basic] saved 730/735 pending answers.
# [basic] saved 735/735 pending answers.
# [basic] complete: D:\Personal Project\RAG In Cancer Myth\rag-cancer-myth\non_rag\gpt-5.6-luna\answers_basic.csv
#
# [oncology_expert] selected=735, completed=0, pending=735, workers=16
# [oncology_expert] saved 1/735 pending answers.
# [oncology_expert] saved 10/735 pending answers.
# [oncology_expert] saved 20/735 pending answers.
# [oncology_expert] saved 30/735 pending answers.
# [oncology_expert] saved 40/735 pending answers.
# [oncology_expert] saved 50/735 pending answers.
# [oncology_expert] saved 60/735 pending answers.
# [oncology_expert] saved 70/735 pending answers.
# [oncology_expert] saved 80/735 pending answers.
# [oncology_expert] saved 90/735 pending answers.
# [oncology_expert] saved 100/735 pending answers.
# [oncology_expert] saved 110/735 pending answers.
# [oncology_expert] saved 120/735 pending answers.
# [oncology_expert] saved 130/735 pending answers.
# [oncology_expert] saved 140/735 pending answers.
# [oncology_expert] saved 150/735 pending answers.
# [oncology_expert] saved 160/735 pending answers.
# [oncology_expert] saved 170/735 pending answers.
# [oncology_expert] saved 180/735 pending answers.
# [oncology_expert] saved 190/735 pending answers.
# [oncology_expert] saved 200/735 pending answers.
# [oncology_expert] saved 210/735 pending answers.
# [oncology_expert] saved 220/735 pending answers.
# [oncology_expert] saved 230/735 pending answers.
# [oncology_expert] saved 240/735 pending answers.
# [oncology_expert] saved 250/735 pending answers.
# [oncology_expert] saved 260/735 pending answers.
# [oncology_expert] saved 270/735 pending answers.
# [oncology_expert] saved 280/735 pending answers.
# [oncology_expert] saved 290/735 pending answers.
# [oncology_expert] saved 300/735 pending answers.
# [oncology_expert] saved 310/735 pending answers.
# [oncology_expert] saved 320/735 pending answers.
# [oncology_expert] saved 330/735 pending answers.
# [oncology_expert] saved 340/735 pending answers.
# [oncology_expert] saved 350/735 pending answers.
# [oncology_expert] saved 360/735 pending answers.
# [oncology_expert] saved 370/735 pending answers.
# [oncology_expert] saved 380/735 pending answers.
# [oncology_expert] saved 390/735 pending answers.
# [oncology_expert] saved 400/735 pending answers.
# [oncology_expert] saved 410/735 pending answers.
# [oncology_expert] saved 420/735 pending answers.
# [oncology_expert] saved 430/735 pending answers.
# [oncology_expert] saved 440/735 pending answers.
# [oncology_expert] saved 450/735 pending answers.
# [oncology_expert] saved 460/735 pending answers.
# [oncology_expert] saved 470/735 pending answers.
# [oncology_expert] saved 480/735 pending answers.
# [oncology_expert] saved 490/735 pending answers.
# [oncology_expert] saved 500/735 pending answers.
# [oncology_expert] saved 510/735 pending answers.
# [oncology_expert] saved 520/735 pending answers.
# [oncology_expert] saved 530/735 pending answers.
# [oncology_expert] saved 540/735 pending answers.
# [oncology_expert] saved 550/735 pending answers.
# [oncology_expert] saved 560/735 pending answers.
# [oncology_expert] saved 570/735 pending answers.
# [oncology_expert] saved 580/735 pending answers.
# [oncology_expert] saved 590/735 pending answers.
# [oncology_expert] saved 600/735 pending answers.
# [oncology_expert] saved 610/735 pending answers.
# [oncology_expert] saved 620/735 pending answers.
# [oncology_expert] saved 630/735 pending answers.
# [oncology_expert] saved 640/735 pending answers.
# [oncology_expert] saved 650/735 pending answers.
# [oncology_expert] saved 660/735 pending answers.
# [oncology_expert] saved 670/735 pending answers.
# [oncology_expert] saved 680/735 pending answers.
# [oncology_expert] saved 690/735 pending answers.
# [oncology_expert] saved 700/735 pending answers.
# [oncology_expert] saved 710/735 pending answers.
# [oncology_expert] saved 720/735 pending answers.
# [oncology_expert] saved 730/735 pending answers.
# [oncology_expert] saved 735/735 pending answers.
# [oncology_expert] complete: D:\Personal Project\RAG In Cancer Myth\rag-cancer-myth\non_rag\gpt-5.6-luna\answers_oncology_expert.csv
#
# [patient_education] selected=735, completed=0, pending=735, workers=16
# [patient_education] saved 1/735 pending answers.
# [patient_education] saved 10/735 pending answers.
# [patient_education] saved 20/735 pending answers.
# [patient_education] saved 30/735 pending answers.
# [patient_education] saved 40/735 pending answers.
# [patient_education] saved 50/735 pending answers.
# [patient_education] saved 60/735 pending answers.
# [patient_education] saved 70/735 pending answers.
# [patient_education] saved 80/735 pending answers.
# [patient_education] saved 90/735 pending answers.
# [patient_education] saved 100/735 pending answers.
# [patient_education] saved 110/735 pending answers.
# [patient_education] saved 120/735 pending answers.
# [patient_education] saved 130/735 pending answers.
# [patient_education] saved 140/735 pending answers.
# [patient_education] saved 150/735 pending answers.
# [patient_education] saved 160/735 pending answers.
# [patient_education] saved 170/735 pending answers.
# [patient_education] saved 180/735 pending answers.
# [patient_education] saved 190/735 pending answers.
# [patient_education] saved 200/735 pending answers.
# [patient_education] saved 210/735 pending answers.
# [patient_education] saved 220/735 pending answers.
# [patient_education] saved 230/735 pending answers.
# [patient_education] saved 240/735 pending answers.
# [patient_education] saved 250/735 pending answers.
# [patient_education] saved 260/735 pending answers.
# [patient_education] saved 270/735 pending answers.
# [patient_education] saved 280/735 pending answers.
# [patient_education] saved 290/735 pending answers.
# [patient_education] saved 300/735 pending answers.
# [patient_education] saved 310/735 pending answers.
# [patient_education] saved 320/735 pending answers.
# [patient_education] saved 330/735 pending answers.
# [patient_education] saved 340/735 pending answers.
# [patient_education] saved 350/735 pending answers.
# [patient_education] saved 360/735 pending answers.
# [patient_education] saved 370/735 pending answers.
# [patient_education] saved 380/735 pending answers.
# [patient_education] saved 390/735 pending answers.
# [patient_education] saved 400/735 pending answers.
# [patient_education] saved 410/735 pending answers.
# [patient_education] saved 420/735 pending answers.
# [patient_education] saved 430/735 pending answers.
# [patient_education] saved 440/735 pending answers.
# [patient_education] saved 450/735 pending answers.
# [patient_education] saved 460/735 pending answers.
# [patient_education] saved 470/735 pending answers.
# [patient_education] saved 480/735 pending answers.
# [patient_education] saved 490/735 pending answers.
# [patient_education] saved 500/735 pending answers.
# [patient_education] saved 510/735 pending answers.
# [patient_education] saved 520/735 pending answers.
# [patient_education] saved 530/735 pending answers.
# [patient_education] saved 540/735 pending answers.
# [patient_education] saved 550/735 pending answers.
# [patient_education] saved 560/735 pending answers.
# [patient_education] saved 570/735 pending answers.
# [patient_education] saved 580/735 pending answers.
# [patient_education] saved 590/735 pending answers.
# [patient_education] saved 600/735 pending answers.
# [patient_education] saved 610/735 pending answers.
# [patient_education] saved 620/735 pending answers.
# [patient_education] saved 630/735 pending answers.
# [patient_education] saved 640/735 pending answers.
# [patient_education] saved 650/735 pending answers.
# [patient_education] saved 660/735 pending answers.
# [patient_education] saved 670/735 pending answers.
# [patient_education] saved 680/735 pending answers.
# [patient_education] saved 690/735 pending answers.
# [patient_education] saved 700/735 pending answers.
# [patient_education] saved 710/735 pending answers.
# [patient_education] saved 720/735 pending answers.
# [patient_education] saved 730/735 pending answers.
# [patient_education] saved 735/735 pending answers.
# [patient_education] complete: D:\Personal Project\RAG In Cancer Myth\rag-cancer-myth\non_rag\gpt-5.6-luna\answers_patient_education.csv

# %%
for output_path in output_paths:
    completed_ids = load_completed_ids(output_path)
    selected_ids = {str(row["id"]) for row in selected_questions}
    missing_ids = selected_ids - completed_ids
    print(f"{output_path.name}: {len(selected_ids - missing_ids)}/{len(selected_ids)} selected questions saved")
    assert not missing_ids, f"{output_path.name} is missing selected IDs: {sorted(missing_ids)}"
# Out:
# answers_basic.csv: 735/735 selected questions saved
# answers_oncology_expert.csv: 735/735 selected questions saved
# answers_patient_education.csv: 735/735 selected questions saved
